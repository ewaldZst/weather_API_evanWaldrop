# %%
import requests
import pandas as pd

# %%
baseurl = 'http://api.weatherapi.com/v1'
api_key = "xxxxx" #removed for submission

# %%
#http://api.weatherapi.com/v1/current.json?key=<YOUR_API_KEY>&q=London

# %%
city = "Louisville"
baseurl = f"http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}"
response = requests.get(baseurl)

# %%
response.status_code
# Out:
# 401

# %%
data = response.json()
data
# Out:
# {'error': {'code': 2006, 'message': 'API key is invalid.'}}

# %%
current = data['current']
location = data['location']
temp_f = current['temp_f']
wind_mph = current['wind_mph']
humidity = current['humidity']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 current = data['current']
#       2 location = data['location']
#       3 temp_f = current['temp_f']
#
# KeyError: 'current'

# %%
def get_weather(city):
    url = f"http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        current = data['current']
        location = data['location']
        temp_f = current['temp_f']
        wind_mph = current['wind_mph']
        humidity = current['humidity']

        print(f"Weather for {location['name']}, {location['region']}")
        print(f"Temperature: {current['temp_f']} degrees F")
        print(f"Condition: {current['condition']['text']}")
        print(f"Humidity: {current['humidity']}%")
        print(f"Wind Speed: {current['wind_mph']} mph")
    else:
        print(f"Error fetching data for {city}: {response.status_code}")

# %%
get_weather("Indianapolis")
# Out:
# Weather for Indianapolis, Indiana
# Temperature: 43.0 degrees F
# Condition: Partly cloudy
# Humidity: 89%
# Wind Speed: 6.7 mph

# %%
get_weather("Munich")
# Out:
# Weather for Munich, Bayern
# Temperature: 20.1 degrees F
# Condition: Overcast
# Humidity: 100%
# Wind Speed: 2.7 mph

# %%
get_weather("adsfaf")
# Out:
# Error fetching data for adsfaf: 400

# %%
get_weather("Cape Town")
# Out:
# Weather for Cape Town, Western Cape
# Temperature: 62.8 degrees F
# Condition: Clear
# Humidity: 88%
# Wind Speed: 8.9 mph

# %%
cities = ["Bloomington", "Louisville", "Seattle", "Glasgow"]
weather_data = []

for city in cities:
    url = f"http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        weather_data.append({
            "City": data['location']['name'],
            "Temperature": data['current']['temp_f'],
            "Condition": data['current']['condition']['text'],
            "Humidity": data['current']['humidity'],
            "Wind Speed": data['current']['wind_mph']
        })
    else:
        print("Error fetching data")

# %%
weather_data
# Out:
# [{'City': 'Bloomington',
#   'Temperature': 30.9,
#   'Condition': 'Overcast',
#   'Humidity': 89,
#   'Wind Speed': 4.5},
#  {'City': 'Louisville',
#   'Temperature': 51.1,
#   'Condition': 'Clear',
#   'Humidity': 83,
#   'Wind Speed': 6.3},
#  {'City': 'Seattle',
#   'Temperature': 45.0,
#   'Condition': 'Overcast',
#   'Humidity': 86,
#   'Wind Speed': 10.3},
#  {'City': 'Glasgow',
#   'Temperature': 39.2,
#   'Condition': 'Partly cloudy',
#   'Humidity': 81,
#   'Wind Speed': 10.7}]

# %%
weather_df = pd.DataFrame(weather_data)

# %%
weather_df
# Out:
#           City  Temperature      Condition  Humidity  Wind Speed
# 0  Bloomington         30.9       Overcast        89         4.5
# 1   Louisville         51.1          Clear        83         6.3
# 2      Seattle         45.0       Overcast        86        10.3
# 3      Glasgow         39.2  Partly cloudy        81        10.7

# %%
weather_df.to_csv('sample_weather_data.csv', index=False)

# %%
city = "Louisville"
baseurl = 'http://api.weatherapi.com/v1'
forecast_url = f"{baseurl}/forecast.json?key={api_key}&q={city}&days=3"
forecast_response = requests.get(forecast_url)
forecast_response.status_code
# Out:
# 200

# %%
forecast_data = forecast_response.json()
forecast = forecast_data['forecast']['forecastday']

# %%
forecast_3_days_summary = []
for day in forecast:
    forecast_3_days_summary.append(f"{day['date']}: High {day['day']['maxtemp_f']}F, Low {day['day']['mintemp_f']}F - {day['day']['condition']['text']}")

# %%
forecast_3_days_summary
# Out:
# ['2026-01-06: High 57.0F, Low 42.3F - Patchy rain nearby',
#  '2026-01-07: High 46.2F, Low 40.5F - Overcast ',
#  '2026-01-08: High 52.7F, Low 36.3F - Fog']

# %%
from datetime import datetime

# %%
forecast_3_days_summary = []
for day in forecast:
    date_obj = datetime.strptime(day['date'], '%Y-%m-%d')
    formatted_date = date_obj.strftime('%A, %B %#d')
    forecast_3_days_summary.append(f"{formatted_date}: High {day['day']['maxtemp_f']}F / Low {day['day']['mintemp_f']}F - {day['day']['condition']['text']}")

# %%
forecast_3_days_summary
# Out:
# ['Tuesday, January 06: High 57.0F / Low 42.3F - Patchy rain nearby',
#  'Wednesday, January 07: High 46.2F / Low 40.5F - Overcast ',
#  'Thursday, January 08: High 52.7F / Low 36.3F - Fog']

# %%
today = pd.Timestamp.now().strftime("%Y-%m-%d")
astronomy_url = f"{baseurl}astronomy.json?key={api_key}&q={city}&dt={today}"

# %%
#get current weather
    #get a forecast
    #get some astronomical data
    #get anything else as a challenge

    #build a summary for the city, save that summary into a dictionary


def get_city_data(city, api_key):

    base_url = f"http://api.weatherapi.com/v1/forecast.json?key={api_key}&q={city}&days=3"
    response = requests.get(base_url)
    if response.status_code == 200:
        pass
        
    else:
        print("Error fetching data")

    data = response.json()

    current_data = {
        "City": data["location"]["name"],
        "Temp F": data["current"]["temp_f"],
        "Humidity": data["current"]["humidity"],
        "UV": data["current"]["uv"]
    }

    forecast_three_days = []
    for day in data["forecast"]["forecastday"]:
        dayNum = day["date"]
        astronomy = day["astro"]

        forecast_three_days.append({
            "Date": dayNum,
            "High Temp": day["day"]["maxtemp_f"],
            "Low Temp": day["day"]["mintemp_f"],
            "Rain Chance": day["day"].get("daily_chance_of_rain"),

            "Sunrise": astronomy.get("sunrise"),
            "Sunset": astronomy.get("sunset"),
            "Moon Phase": astronomy.get("moon_phase")

        })

    summary = {
        "City": city,
        "Current": current_data,
        "Three Day Forecast": forecast_three_days
    }

    return summary

# %%
print(get_city_data("Louisville", api_key))
# Out:
# {'City': 'Louisville', 'Current': {'City': 'Louisville', 'Temp F': 45.0, 'Humidity': 97, 'UV': 0.0}, 'Three Day Forecast': [{'Date': '2026-01-06', 'High Temp': 57.0, 'Low Temp': 42.3, 'Rain Chance': 89, 'Sunrise': '08:00 AM', 'Sunset': '05:38 PM', 'Moon Phase': 'Waning Gibbous'}, {'Date': '2026-01-07', 'High Temp': 46.2, 'Low Temp': 40.5, 'Rain Chance': 0, 'Sunrise': '08:00 AM', 'Sunset': '05:39 PM', 'Moon Phase': 'Waning Gibbous'}, {'Date': '2026-01-08', 'High Temp': 52.7, 'Low Temp': 36.3, 'Rain Chance': 0, 'Sunrise': '08:00 AM', 'Sunset': '05:40 PM', 'Moon Phase': 'Waning Gibbous'}]}

# %%
#build a DF with the city data and save it into a csv

# %%
csv_data = get_city_data("Louisville", api_key)

rows = []

for day in csv_data["Three Day Forecast"]:
    row = {
        "City": csv_data["City"],
        "Date": day["Date"],
        "High Temp": day["High Temp"],
        "Low Temp": day["Low Temp"],
        "Rain Chance": day["Rain Chance"],
        "Sunrise": day["Sunrise"],
        "Sunset": day["Sunset"],
        "Moon Phase": day["Moon Phase"],
    }
    rows.append(row)


forecast_df = pd.DataFrame(rows)
forecast_df.to_csv("three_day_forecast.csv", index=False)
