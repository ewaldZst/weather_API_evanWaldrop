# %%
baseurl = 'http://api.weatherapi.com/v1'
api_key = 'bda1a1ac0bb0489c99613505251712'

# %%
#http://api.weatherapi.com/v1/current.json?key=<YOUR_API_KEY>&q=London

# %%
import requests
import pandas as pd

# %%
city = "Louisville"
baseurl = f"http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}"
response = requests.get(baseurl)

# %%
response.status_code
# Out:
# 200

# %%
data = response.json()
data
# Out:
# {'location': {'name': 'Louisville',
#   'region': 'Kentucky',
#   'country': 'United States of America',
#   'lat': 38.2542,
#   'lon': -85.7594,
#   'tz_id': 'America/Kentucky/Louisville',
#   'localtime_epoch': 1765937243,
#   'localtime': '2025-12-16 21:07'},
#  'current': {'last_updated_epoch': 1765936800,
#   'last_updated': '2025-12-16 21:00',
#   'temp_c': 5.2,
#   'temp_f': 41.4,
#   'is_day': 0,
#   'condition': {'text': 'Overcast',
#    'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#    'code': 1009},
#   'wind_mph': 9.8,
#   'wind_kph': 15.8,
#   'wind_degree': 200,
#   'wind_dir': 'SSW',
#   'pressure_mb': 1017.0,
#   'pressure_in': 30.03,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 39,
#   'cloud': 100,
#   'feelslike_c': 1.9,
#   'feelslike_f': 35.4,
#   'windchill_c': -0.3,
#   'windchill_f': 31.4,
#   'heatindex_c': 2.6,
#   'heatindex_f': 36.7,
#   'dewpoint_c': -2.2,
#   'dewpoint_f': 28.0,
#   'vis_km': 16.0,
#   'vis_miles': 9.0,
#   'uv': 0.0,
#   'gust_mph': 20.0,
#   'gust_kph': 32.3,
#   'short_rad': 0,
#   'diff_rad': 0,
#   'dni': 0,
#   'gti': 0}}

# %%
current = data['current']
location = data['location']
temp_f = current['temp_f']
wind_mph = current['wind_mph']
humidity = current['humidity']

# %%
def get_weather(city):
    url = f"http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        current = data['current']
        location = data['location']
        temp_f = current['temp_f']
        wind_mph = current['wind_mph']
        humidity = current['humidity']

        print(f"Weather for {location['name']}, {location['region']}")
        print(f"Temperature: {current['temp_f']} degrees F")
        print(f"Condition: {current['condition']['text']}")
        print(f"Humidity: {current['humidity']}%")
        print(f"Wind Speed: {current['wind_mph']} mph")
    else:
        print(f"Error fetching data for {city}: {response.status_code}")

# %%
get_weather("Indianapolis")
# Out:
# Weather for Indianapolis, Indiana
# Temperature: 37.0 degrees F
# Condition: Overcast
# Humidity: 64%
# Wind Speed: 11.0 mph

# %%
get_weather("Munich")
# Out:
# Weather for Munich, Bayern
# Temperature: 32.2 degrees F
# Condition: Mist
# Humidity: 100%
# Wind Speed: 4.7 mph

# %%
get_weather("adsfaf")
# Out:
# Error fetching data for adsfaf: 400

# %%
get_weather("Cape Town")
# Out:
# Weather for Cape Town, Western Cape
# Temperature: 62.6 degrees F
# Condition: Partly cloudy
# Humidity: 77%
# Wind Speed: 11.2 mph

# %%
cities = ["Bloomington", "Louisville", "Seattle", "Glasgow"]
weather_data = []

for city in cities:
    url = f"http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        weather_data.append({
            "City": data['location']['name'],
            "Temperature": data['current']['temp_f'],
            "Condition": data['current']['condition']['text'],
            "Humidity": data['current']['humidity'],
            "Wind Speed": data['current']['wind_mph']
        })
    else:
        print("Error fetching data")

# %%
weather_data
# Out:
# [{'City': 'Bloomington',
#   'Temperature': 39.9,
#   'Condition': 'Partly cloudy',
#   'Humidity': 73,
#   'Wind Speed': 13.2},
#  {'City': 'Louisville',
#   'Temperature': 41.5,
#   'Condition': 'Overcast',
#   'Humidity': 39,
#   'Wind Speed': 8.5},
#  {'City': 'Seattle',
#   'Temperature': 54.0,
#   'Condition': 'Light rain',
#   'Humidity': 86,
#   'Wind Speed': 15.0},
#  {'City': 'Glasgow',
#   'Temperature': 43.2,
#   'Condition': 'Patchy rain nearby',
#   'Humidity': 87,
#   'Wind Speed': 10.7}]

# %%
weather_df = pd.DataFrame(weather_data)

# %%
weather_df
# Out:
#           City  Temperature           Condition  Humidity  Wind Speed
# 0  Bloomington         39.9       Partly cloudy        73        13.2
# 1   Louisville         41.5            Overcast        39         8.5
# 2      Seattle         54.0          Light rain        86        15.0
# 3      Glasgow         43.2  Patchy rain nearby        87        10.7

# %%
weather_df.to_csv('sample_weather_data.csv', index=False)
